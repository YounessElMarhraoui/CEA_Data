# %%
import os

import itertools

import numpy as np
import pandas as pd

from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score

from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

import tensorflow as tf

from scipy.fft import fft, dct
import scipy.stats as stats

import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('max_columns', None)

# %%
DATA_PATH = '../../Data/TRANSFORMED_DATA/lr_transformed_cea_data.csv'

# %%
class varyingFrameConstructor:
    """
    A class to generate frames of data based on varying window sizes.
    The window sizes are computed from the length of each action .

    ...

    Attributes
    ----------
    frames : list
       the list of sliced dataframes
       
    Methods
    -------
    df_to_variate_frames
       Creates a tuple of the frames containing the sequence of temporal series and the corresponding 
       labels. Each frame is reduced to a vactor thanks to a PCA algorithm
    df_to_variate_dct_frames
       Creates a tuple of the frames containing the DCT transform of the sequence of temporal series 
       and the corresponding labels. Each frame is reduced to a vactor thanks to a PCA algorithm
    df_to_variate_fft_frames
       Creates a tuple of the frames containing the FFT transform of the sequence of temporal series 
       and the corresponding labels. Each frame is reduced to a vactor thanks to a PCA algorithm
    """
    def __init__(self, frames):
        """
        Initialize list of frames

        ...

        Parameters
        ----------
        frames : list
           the list of sliced dataframes
        """
        self.frames = frames
        
    def df_to_variate_frames(self):
        """Creates a tuple of the frames containing the sequence of temporal series and the corresponding 
        labels. Each frame is reduced to a vactor thanks to a PCA algorithm

        Returns
        -------
        frames : array
            An array containing sub-arrays of each reduced frame of data
        labels : array
            An array containing labels corresponding to each sub-frame
        """
        min_len_frame = min([len(frame) for frame in self.frames])
        n_components = min(min_len_frame, 6)
        frames = []
        labels = []
        for i in range(0, len(self.frames)):
            acc_x = self.frames[i]['Acc_x']
            acc_y = self.frames[i]['Acc_y']
            acc_z = self.frames[i]['Acc_z']

            gyro_x = self.frames[i]['Gyro_x']
            gyro_y = self.frames[i]['Gyro_y']
            gyro_z = self.frames[i]['Gyro_z']

            label = self.frames[i]['appui_leve'].unique()
            temp_frame = np.asarray([acc_x, acc_y, acc_z, gyro_x, gyro_y, gyro_z])

            pca = PCA(n_components=n_components)
            pca.fit(temp_frame)
            temp_frame = pca.transform(temp_frame)

            frames.append(temp_frame)
            labels.append(label)

        frames = np.asarray(frames).reshape(-1, 6 * n_components)
        labels = np.asarray(labels)

        return frames, labels
    
    def df_to_variate_dct_frames(self):
        """Creates a tuple of the frames containing the DCT transform of the sequence of temporal series 
        and the corresponding labels. Each frame is reduced to a vactor thanks to a PCA algorithm
        
        Returns
        -------
        frames : array
            An array containing sub-arrays of each reduced frame of data
        labels : array
            An array containing labels corresponding to each sub-frame
        """
        min_len_frame = min([len(frame) for frame in self.frames])
        n_components = min(min_len_frame, 6)
        frames = []
        labels = []
        for i in range(0, len(self.frames)):
            acc_x = dct(self.frames[i]['Acc_x'].values)
            acc_y = dct(self.frames[i]['Acc_y'].values)
            acc_z = dct(self.frames[i]['Acc_z'].values)

            gyro_x = dct(self.frames[i]['Gyro_x'].values)
            gyro_y = dct(self.frames[i]['Gyro_y'].values)
            gyro_z = dct(self.frames[i]['Gyro_z'].values)

            label = self.frames[i]['appui_leve'].unique()
            temp_frame = np.asarray([acc_x, acc_y, acc_z, gyro_x, gyro_y, gyro_z])

            pca = PCA(n_components=n_components)
            pca.fit(temp_frame)
            temp_frame = pca.transform(temp_frame)

            frames.append(temp_frame)
            labels.append(label)

        frames = np.asarray(frames).reshape(-1, 6 * n_components)
        labels = np.asarray(labels)

        return frames, labels
    
    def df_to_variate_fft_frames(self):
        """Creates a tuple of the frames containing the FFT transform of the sequence of temporal series 
        and the corresponding labels. Each frame is reduced to a vactor thanks to a PCA algorithm
        
        Returns
        -------
        frames : array
            An array containing sub-arrays of each reduced frame of data
        labels : array
            An array containing labels corresponding to each sub-frame
        """
        min_len_frame = min([len(frame) for frame in self.frames])
        n_components = min(min_len_frame, 6)
        frames = []
        labels = []
        for i in range(0, len(self.frames)):
            acc_x = fft(self.frames[i]['Acc_x'].values).real
            acc_y = fft(self.frames[i]['Acc_y'].values).real
            acc_z = fft(self.frames[i]['Acc_z'].values).real

            gyro_x = fft(self.frames[i]['Gyro_x'].values).real
            gyro_y = fft(self.frames[i]['Gyro_y'].values).real
            gyro_z = fft(self.frames[i]['Gyro_z'].values).real

            label = self.frames[i]['appui_leve'].unique()
            temp_frame = np.asarray([acc_x, acc_y, acc_z, gyro_x, gyro_y, gyro_z])

            pca = PCA(n_components=n_components)
            pca.fit(temp_frame)
            temp_frame = pca.transform(temp_frame)

            frames.append(temp_frame)
            labels.append(label)

        frames = np.asarray(frames).reshape(-1, 6 * n_components)
        labels = np.asarray(labels)

        return frames, labels
    
class fixedFrameConstructor:
    """
    A class to generate frames of data based on fixed window size.

    ...

    Attributes
    ----------
    df : dataframe
       the dataframe that contains all of the data
    frame_size : int
       the size of each sliced window
    skip_size : int
       the size of the window that should skipped before creating a new one
    Methods
    -------
    df_to_fixed_frames
       Creates a tuple of the frames containing the sequence of temporal series and the corresponding 
       labels. Each frame is reduced to a vactor thanks to a PCA algorithm
    df_to_fixed_dct_frames
       Creates a tuple of the frames containing the DCT transform of the sequence of temporal series 
       and the corresponding labels. Each frame is reduced to a vactor thanks to a PCA algorithm
    df_to_fixed_fft_frames
       Creates a tuple of the frames containing the FFT transform of the sequence of temporal series 
       and the corresponding labels. Each frame is reduced to a vactor thanks to a PCA algorithm
    """
    def __init__(self, df):
        """
        Initialize the dataframe

        ...

        Parameters
        ----------
        df : dataframe
           the dataframe that contains all of the data
        """
        self.df = df
        
    def df_to_fixed_frames(self, frame_size, skip_size):
        """Creates a tuple of the frames containing the sequence of temporal series and the corresponding 
        labels. Each frame is reduced to a vactor thanks to a PCA algorithm
        
        Parameters
        ----------
        frame_size : int
           the size of each sliced window
        skip_size : int
           the size of the window that should skipped before creating a new one
       
        Returns
        -------
        frames : array
            An array containing sub-arrays of each reduced frame of data
        labels : array
            An array containing labels corresponding to each sub-frame
        """
        n_components = min(frame_size, 6)
        frames = []
        labels = []
        for i in range(0, len(self.df) - frame_size, skip_size):
            acc_x = self.df['Acc_x'].values[i:i+frame_size]
            acc_y = self.df['Acc_y'].values[i:i+frame_size]
            acc_z = self.df['Acc_z'].values[i:i+frame_size]

            gyro_x = self.df['Gyro_x'].values[i:i+frame_size]
            gyro_y = self.df['Gyro_y'].values[i:i+frame_size]
            gyro_z = self.df['Gyro_z'].values[i:i+frame_size]

            label = stats.mode(self.df['appui_leve'][i:i+frame_size])[0][0]

            temp_frame = np.asarray([acc_x, acc_y, acc_z, gyro_x, gyro_y, gyro_z])
            pca = PCA(n_components=n_components)
            pca.fit(temp_frame)
            temp_frame = pca.transform(temp_frame)
            frames.append(temp_frame)
            labels.append(label)

        frames = np.asarray(frames).reshape(-1, 6 * n_components)
        labels = np.asarray(labels)

        return frames, labels
    
    def df_to_fixed_dct_frames(self, frame_size, skip_size):
        """Creates a tuple of the frames containing the DCT transform of the sequence of temporal series 
        and the corresponding labels. Each frame is reduced to a vactor thanks to a PCA algorithm
        
        Parameters
        ----------
        frame_size : int
           the size of each sliced window
        skip_size : int
           the size of the window that should skipped before creating a new one
       
        Returns
        -------
        frames : array
            An array containing sub-arrays of each reduced frame of data
        labels : array
            An array containing labels corresponding to each sub-frame
        """
        n_components = min(frame_size, 6)
        frames = []
        labels = []
        for i in range(0, len(self.df) - frame_size, skip_size):
            acc_x = dct(self.df['Acc_x'].values[i:i+frame_size])
            acc_y = dct(self.df['Acc_y'].values[i:i+frame_size])
            acc_z = dct(self.df['Acc_z'].values[i:i+frame_size])

            gyro_x = dct(self.df['Gyro_x'].values[i:i+frame_size])
            gyro_y = dct(self.df['Gyro_y'].values[i:i+frame_size])
            gyro_z = dct(self.df['Gyro_z'].values[i:i+frame_size])

            label = stats.mode(self.df['appui_leve'][i:i+frame_size])[0][0]

            temp_frame = np.asarray([acc_x, acc_y, acc_z, gyro_x, gyro_y, gyro_z])
            pca = PCA(n_components=n_components)
            pca.fit(temp_frame)
            temp_frame = pca.transform(temp_frame)
            frames.append(temp_frame)
            labels.append(label)

        frames = np.asarray(frames).reshape(-1, 6 * n_components)
        labels = np.asarray(labels)

        return frames, labels
    
    def df_to_fixed_fft_frames(self, frame_size, skip_size):
        """Creates a tuple of the frames containing the FFT transform of the sequence of temporal series 
        and the corresponding labels. Each frame is reduced to a vactor thanks to a PCA algorithm
        
        Parameters
        ----------
        frame_size : int
           the size of each sliced window
        skip_size : int
           the size of the window that should skipped before creating a new one
       
        Returns
        -------
        frames : array
            An array containing sub-arrays of each reduced frame of data
        labels : array
            An array containing labels corresponding to each sub-frame
        """
        n_components = min(frame_size, 6)
        frames = []
        labels = []
        for i in range(0, len(self.df) - frame_size, skip_size):
            acc_x = fft(self.df['Acc_x'].values[i:i+frame_size]).real
            acc_y = fft(self.df['Acc_y'].values[i:i+frame_size]).real
            acc_z = fft(self.df['Acc_z'].values[i:i+frame_size]).real

            gyro_x = fft(self.df['Gyro_x'].values[i:i+frame_size]).real
            gyro_y = fft(self.df['Gyro_y'].values[i:i+frame_size]).real
            gyro_z = fft(self.df['Gyro_z'].values[i:i+frame_size]).real

            label = stats.mode(self.df['appui_leve'][i:i+frame_size])[0][0]

            temp_frame = np.asarray([acc_x, acc_y, acc_z, gyro_x, gyro_y, gyro_z])
            pca = PCA(n_components=n_components)
            pca.fit(temp_frame)
            temp_frame = pca.transform(temp_frame)
            frames.append(temp_frame)
            labels.append(label)

        frames = np.asarray(frames).reshape(-1, 6 * n_components)
        labels = np.asarray(labels)

        return frames, labels

# %%
class FormatData:
    """
    A class to generate a dictionnary containing training and test data as well as frames and 
    dataframes that are sessential to recreate the original signal.

    ...

    Attributes
    ----------
    data_path : str
       the path to the csv file
    id_out : str
       the ID of the patient to use for test data
    train_df : dataframe
       the data frame created from the list patient IDs used fot the training set
    test_df : dataframe
       the data frame created from the patient ID used fot the test set
    train_var_frames : list
       the list of frames created from the training data
    test_var_frames : list
       the list of frames created from the test data
    transform : str
       the name of transform to use for data (None, dct or fft)
    window_size : int
       the size of each sliced window
    skip_size : int
       the size of the window that should skipped before creating a new one
    window_type : str
       the type of window to use, fixed or vary
    
    Methods
    -------
    loso_split
       Splits data into training and test data by Leaving One Subject One
    variate_window_df
       Creates a list of frames based on the target variable, each time
       the value of the target is swithing a new frame is created
    create_variate_frames
       Creates data matrices as well as the targets for both training and testing
    create_fixed_frames
       Creates data matrices as well as the targets for both training and testing
    """
    def __init__(self, data_path):
        """
        Initialize path to the data file, reads the file and initializes the data matrices

        ...

        Parameters
        ----------
        data_path : str
            The path leading to the data file
        """
        self.data_path = data_path
        self.data = pd.read_csv(self.data_path)
        
        self.X_train = []
        self.X_test = []
        self.y_train = []
        self.y_test = []
        
    def loso_split(self, id_out='P42'):
        """Splits data into training and test data by Leaving One Subject One

        Parameters
        ----------
        id_out : str
            the ID of the patient to use for test data

        Returns
        -------
        train_df : dataframe
           the data frame created from the list patient IDs used fot the training set
        test_df : dataframe
           the data frame created from the patient ID used fot the test set
        """
        train_df = self.data[self.data.id_pat != id_out]
        test_df = self.data[self.data.id_pat == id_out]
        return train_df, test_df
    
    def variate_window_df(self, train_df, test_df):
        """Creates a list of frames based on the target variable, each time
        the value of the target is swithing a new frame is created

        Parameters
        ----------
        train_df : dataframe
           the data frame created from the list patient IDs used fot the training set
        test_df : dataframe
           the data frame created from the patient ID used fot the test set

        Returns
        -------
        train_var_frames : list
           the list of frames created from the training data
        test_var_frames : list
           the list of frames created from the test data
        """
        train_df['groups'] = (train_df.appui_leve != train_df.appui_leve.shift(1)).cumsum()
        test_df['groups'] = (test_df.appui_leve != test_df.appui_leve.shift(1)).cumsum()
        
        train_var_frames = [frame for _,frame in train_df.groupby('groups')]
        test_var_frames = [frame for _,frame in test_df.groupby('groups')]
        return train_var_frames, test_var_frames
    
    def create_variate_frames(self, train_var_frames, test_var_frames, transform=None):
        """Creates a list of frames based on the target variable, each time
        the value of the target is swithing a new frame is created

        Parameters
        ----------
        train_var_frames : list
           the list of frames created from the training data
        test_var_frames : list
           the list of frames created from the test data
        transform : str
           the name of transform to use for data (None, dct or fft)

        Returns
        -------
        X_train : array
           an array that contains the training data
        X_test : array
           an array that contains the test data
        y_train : array
           an array that contains labels for the training data
        y_test : array
           an array that contains labels for the test data
        """
        if transform is None:
            frame_constructor = varyingFrameConstructor(train_var_frames)
            X_train, y_train = frame_constructor.df_to_variate_frames()
            frame_constructor = varyingFrameConstructor(test_var_frames)
            X_test, y_test = frame_constructor.df_to_variate_frames()
        elif transform == 'dct':
            frame_constructor = varyingFrameConstructor(train_var_frames)
            X_train, y_train = frame_constructor.df_to_variate_dct_frames()
            frame_constructor = varyingFrameConstructor(test_var_frames)
            X_test, y_test = frame_constructor.df_to_variate_dct_frames()
        elif transform == 'fft':
            frame_constructor = varyingFrameConstructor(train_var_frames)
            X_train, y_train = frame_constructor.df_to_variate_fft_frames()
            frame_constructor = varyingFrameConstructor(test_var_frames)
            X_test, y_test = frame_constructor.df_to_variate_fft_frames()
            
        return X_train, X_test, y_train, y_test
    
    def create_fixed_frames(self, train_df, test_df, window_size, skip_size, transform=None):
        """Creates a list of frames based on the chosen window, it 
        corresponds to the most frequent label in each window

        Parameters
        ----------
        train_df : dataframe
           the data frame created from the list patient IDs used fot the training set
        test_df : dataframe
           the data frame created from the patient ID used fot the test set
        window_size : int
           the size of each sliced window
        skip_size : int
           the size of the window that should skipped before creating a new one
        transform : str
           the name of transform to use for data (None, dct or fft)

        Returns
        -------
        X_train : array
           an array that contains the training data
        X_test : array
           an array that contains the test data
        y_train : array
           an array that contains labels for the training data
        y_test : array
           an array that contains labels for the test data
        """
        if transform is None:
            frame_constructor = fixedFrameConstructor(train_df)
            X_train, y_train = frame_constructor.df_to_fixed_frames(window_size, skip_size)
            frame_constructor = fixedFrameConstructor(test_df)
            X_test, y_test = frame_constructor.df_to_fixed_frames(window_size, skip_size)
        elif transform == 'dct':
            frame_constructor = fixedFrameConstructor(train_df)
            X_train, y_train = frame_constructor.df_to_fixed_dct_frames(window_size, skip_size)
            frame_constructor = fixedFrameConstructor(test_df)
            X_test, y_test = frame_constructor.df_to_fixed_dct_frames(window_size, skip_size)
        elif transform == 'fft':
            frame_constructor = fixedFrameConstructor(train_df)
            X_train, y_train = frame_constructor.df_to_fixed_fft_frames(window_size, skip_size)
            frame_constructor = fixedFrameConstructor(test_df)
            X_test, y_test = frame_constructor.df_to_fixed_fft_frames(window_size, skip_size)
            
        return X_train, X_test, y_train, y_test
    
    def __call__(self, window_type, window_size=None, skip_size=None):
        """Applies transforms after class instance being called

        Parameters
        ----------
        window_type : str
           the type of window to use, fixed or vary
        window_size : int
           the size of each sliced window
        skip_size : int
           the size of the window that should skipped before creating a new one
    

        Returns
        -------
        my_frames : dict
           the dictionary that contains all of the combinaitions of generated data
        """
        list_transforms = [None, 'dct', 'fft']
        train_df, test_df = self.loso_split()
        my_frames = {}
        if window_type == 'fixed':
            assert (window_size is not None) or (skip_size is not None), "Arguments window_size and skip_size are missing"
            my_frames = {transform:self.create_fixed_frames(train_df, test_df, window_size, skip_size, transform) for transform in list_transforms}
            my_frames['df_test'] = test_df
        elif window_type == 'vary':
            train_var_frames, test_var_frames = self.variate_window_df(train_df, test_df)
            my_frames = {transform:self.create_variate_frames(train_var_frames, test_var_frames, transform) for transform in list_transforms}
            my_frames['test_frames'] = test_var_frames
            my_frames['df_test'] = test_df
        return my_frames

# %%
class MLModels:
    """
    A class to create, train and evaluate ML models (random forest and xgboost)

    ...

    Attributes
    ----------
    frames_dict : dict
       the dictionary that contains all of the combinaitions of generated data
    window_type : str
       the type of window to use, fixed or vary        
    transform_type : str
       the name of transform to use for data (None, dct or fft)
       
    Methods
    -------
    fit_models
       Fits the models on the training data
    evaluate_models
       Evaualtes the predictions made by the models by reformatting them into their initial length
    """
    def __init__(self, frames_dict, window_type, transform_type):
        """
        Initialize dictionary of the different types of frames, the type of 
        windows and the data transformation type as well as the classifiers
        to train

        ...

        Parameters
        ----------
        frames_dict : dict
           the dictionary that contains all of the combinaitions of generated data
        window_type : str
           the type of window to use, fixed or vary        
        transform_type : str
           the name of transform to use for data (None, dct or fft)
        """
        self.frames_dict = frames_dict
        self.window_type = window_type
        self.transform_type = transform_type
        self.X_train, self.X_test, self.y_train, self.y_test = self.frames_dict[self.transform_type]
        self.test_df = {}
        self.test_var_frames = {}
        if self.window_type == 'vary':
            self.test_df = self.frames_dict['df_test']
            self.test_var_frames = self.frames_dict['test_frames']
        elif self.window_type == 'fixed':
            self.test_df = self.frames_dict['df_test']

        self.RFClassifier = RandomForestClassifier(raandom_state=0)
        self.XGBClassifier = XGBClassifier(random_state=0, silent=True)
    
    def fit_models(self):
        """Fits the models on the training data
        """
        self.RFClassifier.fit(self.X_train, self.y_train)
        self.XGBClassifier.fit(self.X_train, self.y_train)
        
    def evaluate_models(self):
        """Evaualtes the predictions made by the models by reformatting them into their initial length
        """
        rf_score = self.RFClassifier.score(self.X_test, self.y_test)
        y_pred_rf = self.RFClassifier.predict(self.X_test)
        if self.window_type == 'vary':
            y_real_test_pred = [[ele]*len(frame) for ele,frame in zip(y_pred_rf, self.test_var_frames)]
            y_real_test_pred = np.asarray(list(itertools.chain(*y_real_test_pred)))
            y_real_test = self.test_df.appui_leve.values
        elif self.window_type == 'fixed':
            y_real_test_pred = [[ele]*window_size for ele in y_pred_rf]
            y_real_test_pred = np.asarray(y_real_test_pred).flatten()
            y_real_test = self.test_df.appui_leve.values[:len(y_real_test_pred)]
        print(y_real_test_pred.shape, y_real_test.shape)
        rf_real_score = accuracy_score(y_real_test_pred, y_real_test)
        print(
        """
        ##################################
        #            RF model            #
        ##################################
        """
        )
        print('Windowed test data score: ', rf_score)
        print('Real test data score: ', rf_real_score)
        
        plt.figure(figsize=(20,5))
        plt.plot(y_real_test)
        plt.plot(y_real_test_pred)
        plt.figure(figsize=(20,5))
        plt.plot(y_real_test)
        plt.figure(figsize=(20,5))
        plt.plot(y_real_test_pred)
        plt.show()
        
        xgb_score = self.XGBClassifier.score(self.X_test, self.y_test)
        y_pred_xgb = self.XGBClassifier.predict(self.X_test)
        if self.window_type == 'vary':
            y_real_test_pred = [[ele]*len(frame) for ele,frame in zip(y_pred_xgb, self.test_var_frames)]
            y_real_test_pred = np.asarray(list(itertools.chain(*y_real_test_pred)))
            y_real_test = self.test_df.appui_leve.values
        elif self.window_type == 'fixed':
            y_real_test_pred = [[ele]*window_size for ele in y_pred_xgb]
            y_real_test_pred = np.asarray(y_real_test_pred).flatten()
            y_real_test = self.test_df.appui_leve.values[:len(y_real_test_pred)]
        
        xgb_real_score = accuracy_score(y_real_test_pred, y_real_test)
        print(
        """
        #################################
        #           XGB model           #
        #################################
        """
        )
        print('Windowed test data score: ', xgb_score)
        print('Real test data score: ', xgb_real_score)
        
        plt.figure(figsize=(20,5))
        plt.plot(y_real_test)
        plt.plot(y_real_test_pred)
        plt.figure(figsize=(20,5))
        plt.plot(y_real_test)
        plt.figure(figsize=(20,5))
        plt.plot(y_real_test_pred)
        plt.show()
        
    def __call__(self):
        self.fit_models()
        self.evaluate_models()

# %%
window_size, skip_size = 10, 10*1
formatted_frames = None
for window_type in ['fixed', 'vary']: 
    data_formattor = FormatData(DATA_PATH)
    if window_type == 'vary':
        formatted_frames = data_formattor(window_type=window_type)
        df_test = formatted_frames['df_test']
        test_var_frames = formatted_frames['test_frames']  
    elif window_type == 'fixed':
        formatted_frames = data_formattor(window_type='fixed', window_size=window_size, skip_size=skip_size)
    for transform_type in [None, 'dct', 'fft']:
        print('#'*70)
        print('WINDOW TYPE: {} - TRANSFORM TYPE: {}'.format(window_type, transform_type))
        print('#'*70)
        model_trainer = MLModels(formatted_frames, window_type, transform_type)
        model_trainer()
# Out:
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: None
# ######################################################################
# [18:46:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:46:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55660,) (55660,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.94699964067553
# Real test data score:  0.9164570607258354
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9398131512756018
# Real test data score:  0.9131512756018685
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: dct
# ######################################################################
# [18:54:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [18:54:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55660,) (55660,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.9455623427955444
# Real test data score:  0.9161696011498383
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9344232842256558
# Real test data score:  0.9112468559108875
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: fft
# ######################################################################
# [19:01:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:01:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55660,) (55660,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.9410707869205893
# Real test data score:  0.9131512756018685
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9358605821056414
# Real test data score:  0.9114265181458857
# ######################################################################
# WINDOW TYPE: vary - TRANSFORM TYPE: None
# ######################################################################
# [19:05:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:05:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55668,) (55668,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.938229238160604
# Real test data score:  0.959743479198103
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9231297185998627
# Real test data score:  0.9443306747143781
# ######################################################################
# WINDOW TYPE: vary - TRANSFORM TYPE: dct
# ######################################################################
# [19:05:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:05:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55668,) (55668,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.8881262868908717
# Real test data score:  0.9364625996982108
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.8544955387783116
# Real test data score:  0.9243371416253503
# ######################################################################
# WINDOW TYPE: vary - TRANSFORM TYPE: fft
# ######################################################################
# [19:05:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:05:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55668,) (55668,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.8737131091283459
# Real test data score:  0.9130919019903715
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9347975291695264
# Real test data score:  0.9265466695408493

# %%
window_size_list = [5, 15, 20, 25, 30]
window_type = 'fixed'
formatted_frames = None
for window_size in window_size_list: 
    skip_size = window_size
    data_formattor = FormatData(DATA_PATH)
    formatted_frames = data_formattor(window_type, window_size=window_size, skip_size=skip_size)
    for transform_type in [None, 'dct', 'fft']:
        print('#'*70)
        print('WINDOW TYPE: {} - TRANSFORM TYPE: {}'.format(window_type, transform_type))
        print('#'*70)
        model_trainer = MLModels(formatted_frames, window_type, transform_type)
        model_trainer()
# Out:
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: None
# ######################################################################
# [23:34:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [23:34:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55665,) (55665,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.9592203359382018
# Real test data score:  0.9464654630378155
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9549088296056768
# Real test data score:  0.9443456390909908
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: dct
# ######################################################################
# [23:50:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [23:50:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55665,) (55665,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.9595796281325788
# Real test data score:  0.9470403305488189
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9533818377795742
# Real test data score:  0.9434294439953292
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: fft
# ######################################################################
# [00:02:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:02:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55665,) (55665,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.9574238749663163
# Real test data score:  0.9456031617713105
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9507769693703404
# Real test data score:  0.9419383813886644
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: None
# ######################################################################
# [00:13:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:13:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55665,) (55665,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.9320937752627324
# Real test data score:  0.8914039342495285
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9293990838049043
# Real test data score:  0.8909368543968382
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: dct
# ######################################################################
# [00:18:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:18:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55665,) (55665,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.9307464295338184
# Real test data score:  0.8925716338812539
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9275127997844247
# Real test data score:  0.8906314560316178
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: fft
# ######################################################################
# [00:22:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:22:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55665,) (55665,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.9296685529506872
# Real test data score:  0.8912063235426211
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9240097008892482
# Real test data score:  0.8901464115692087
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: None
# ######################################################################
# [00:29:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:29:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55660,) (55660,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.9723320158102767
# Real test data score:  0.8860941430111391
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9604743083003953
# Real test data score:  0.8815666546891844
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: dct
# ######################################################################
# [00:32:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:32:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55660,) (55660,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.9683794466403162
# Real test data score:  0.8846568451311534
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9572403880704276
# Real test data score:  0.8807402084081926
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: fft
# ######################################################################
# [00:35:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:35:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55660,) (55660,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.9705353934602946
# Real test data score:  0.8855910887531441
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9554437657204455
# Real test data score:  0.8808839381961912
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: None
# ######################################################################
# [00:41:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:41:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55650,) (55650,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.9860736747529201
# Real test data score:  0.8859658580413298
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9833782569631626
# Real test data score:  0.8846361185983828
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: dct
# ######################################################################
# [00:43:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:43:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55650,) (55650,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.9856244384546271
# Real test data score:  0.8861994609164421
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.981581311769991
# Real test data score:  0.8854986522911051
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: fft
# ######################################################################
# [00:45:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:45:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55650,) (55650,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.9829290206648698
# Real test data score:  0.8845462713387242
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9806828391734053
# Real test data score:  0.8834141958670261
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: None
# ######################################################################
# [00:50:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:50:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55650,) (55650,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.9849056603773585
# Real test data score:  0.8843845462713388
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9762803234501348
# Real test data score:  0.8804312668463612
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: dct
# ######################################################################
# [00:51:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:51:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55650,) (55650,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.9838274932614556
# Real test data score:  0.8842048517520216
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9838274932614556
# Real test data score:  0.8837017070979335
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: fft
# ######################################################################
# [00:53:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:53:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# (55650,) (55650,)
#
#         ##################################
#         #            RF model            #
#         ##################################
#
# Windowed test data score:  0.9849056603773585
# Real test data score:  0.8841329739442947
#         #################################
#         #           XGB model           #
#         #################################
#
# Windowed test data score:  0.9811320754716981
# Real test data score:  0.882336028751123

# %%
class DNNModel(tf.keras.Model):
    """
    A class to create the arcitecture of the DNN model

    ...

    Attributes
    ----------
    inputs : array
       the array of inputs that the model would train on
    """

    def __init__(self):
        """
        Initialize the layers of the model
        """
        super(DNNModel, self).__init__()

        self.fc1 = tf.keras.layers.Dense(64, activation=tf.nn.relu)
        self.fc2 = tf.keras.layers.Dense(32, activation=tf.nn.relu)
        self.fc3 = tf.keras.layers.Dense(1, activation=tf.nn.sigmoid)
    
    def call(self, inputs):
        """Forwad propagates the inputs into the model

        Parameters
        ----------
        inputs : array
           the array of inputs that the model would train on

        Returns
        -------
        x : tensor
            the output of the model
        """
        x = self.fc1(inputs)  
        x = self.fc2(x) 
        x = self.fc3(x)
        return x

# %%
class DNNModelTrain:
    """
    A class to create, train and evaluate the DL model

    ...

    Attributes
    ----------
    frames_dict : dict
       the dictionary that contains all of the combinaitions of generated data
    window_type : str
       the type of window to use, fixed or vary        
    transform_type : str
       the name of transform to use for data (None, dct or fft)
       
    Methods
    -------
    fit_models
       Fits the models on the training data
    evaluate_models
       Evaualtes the predictions made by the models by reformatting them into their initial length
    """
    def __init__(self, frames_dict, window_type, transform_type):):
        """
        Initialize dictionary of the different types of frames, the type of 
        windows and the data transformation type as well as the classifier
        to train

        ...

        Parameters
        ----------
        frames_dict : dict
           the dictionary that contains all of the combinaitions of generated data
        window_type : str
           the type of window to use, fixed or vary        
        transform_type : str
           the name of transform to use for data (None, dct or fft)
        """
        self.frames_dict = frames_dict
        self.window_type = window_type
        self.transform_type = transform_type
        self.X_train, self.X_test, self.y_train, self.y_test = self.frames_dict[self.transform_type]
        self.test_df = {}
        self.test_var_frames = {}
        if self.window_type == 'vary':
            self.test_df = self.frames_dict['df_test']
            self.test_var_frames = self.frames_dict['test_frames']
        elif self.window_type == 'fixed':
            self.test_df = self.frames_dict['df_test']
            
        self.dnn_model = DNNModel()
    
    def fit_models(self, n_epochs=5): 
        """
        Fits model on training data

        ...

        Parameters
        ----------
        n_epochs : int
           number of epochs the model would train on
        """
        
        self.dnn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
        self.dnn_model.fit(self.X_train, self.y_train, epochs=n_epochs)
        
    def evaluate_models(self):
        """Evaualtes the predictions made by the models by reformatting them into their initial length
        """
        dnn_score = self.dnn_model.evaluate(self.X_test, self.y_test)
        y_pred_dnn = self.dnn_model.predict(self.X_test)
        y_pred_dnn = np.where(y_pred_dnn>=0.5, 1, 0)
        if self.window_type == 'vary':
            y_real_test_pred = [[ele]*len(frame) for ele,frame in zip(y_pred_dnn, self.test_var_frames)]
            y_real_test_pred = np.asarray(list(itertools.chain(*y_real_test_pred)))
            y_real_test = self.test_df.appui_leve.values
        elif self.window_type == 'fixed':
            y_real_test_pred = [[ele]*window_size for ele in y_pred_dnn]
            y_real_test_pred = np.asarray(y_real_test_pred).flatten()
            y_real_test = self.test_df.appui_leve.values[:len(y_real_test_pred)]
        print(y_real_test_pred.shape, y_real_test.shape)
        dnn_real_score = accuracy_score(y_real_test_pred, y_real_test)
        print(
        """
        ##################################
        #            DNN model           #
        ##################################
        """
        )
        print('Windowed test data score: ', dnn_score)
        print('Real test data score: ', dnn_real_score)
        
        plt.figure(figsize=(20,5))
        plt.plot(y_real_test)
        plt.plot(y_real_test_pred)
        plt.figure(figsize=(20,5))
        plt.plot(y_real_test)
        plt.figure(figsize=(20,5))
        plt.plot(y_real_test_pred)
        plt.show()
                
    def __call__(self):
        self.fit_models()
        self.evaluate_models()

# %%
window_size, skip_size = 10, 10*1
formatted_frames = None
for window_type in ['vary', 'fixed']: 
    data_formattor = FormatData(DATA_PATH)
    if window_type == 'vary':
        formatted_frames = data_formattor(window_type=window_type)
        df_test = formatted_frames['df_test']
        test_var_frames = formatted_frames['test_frames']  
    elif window_type == 'fixed':
        formatted_frames = data_formattor(window_type='fixed', window_size=window_size, skip_size=skip_size)
    for transform_type in [None, 'dct', 'fft']:
        print('#'*70)
        print('WINDOW TYPE: {} - TRANSFORM TYPE: {}'.format(window_type, transform_type))
        print('#'*70)
        model_trainer = DNNModelTrain(formatted_frames, window_type, transform_type)
        model_trainer()
# Out:
# ######################################################################
# WINDOW TYPE: vary - TRANSFORM TYPE: None
# ######################################################################
# Epoch 1/5
# 1055/1055 [==============================] - 2s 2ms/step - loss: 0.6465 - accuracy: 0.7138
# Epoch 2/5
# 1055/1055 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7886
# Epoch 3/5
# 1055/1055 [==============================] - 2s 1ms/step - loss: 0.4575 - accuracy: 0.8236
# Epoch 4/5
# 1055/1055 [==============================] - 2s 2ms/step - loss: 0.3612 - accuracy: 0.8556
# Epoch 5/5
# 1055/1055 [==============================] - 2s 2ms/step - loss: 0.2997 - accuracy: 0.8868
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2782 - accuracy: 0.8778
# (55668, 1) (55668,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.2782248258590698, 0.8778311610221863]
# Real test data score:  0.873877272400661
# ######################################################################
# WINDOW TYPE: vary - TRANSFORM TYPE: dct
# ######################################################################
# Epoch 1/5
# 1055/1055 [==============================] - 2s 1ms/step - loss: 5.7596 - accuracy: 0.5924
# Epoch 2/5
# 1055/1055 [==============================] - 2s 1ms/step - loss: 2.7608 - accuracy: 0.6323
# Epoch 3/5
# 1055/1055 [==============================] - 2s 1ms/step - loss: 1.7902 - accuracy: 0.6596
# Epoch 4/5
# 1055/1055 [==============================] - 1s 1ms/step - loss: 1.4083 - accuracy: 0.6579
# Epoch 5/5
# 1055/1055 [==============================] - 1s 1ms/step - loss: 1.5476 - accuracy: 0.6561
# 46/46 [==============================] - 0s 1ms/step - loss: 0.8955 - accuracy: 0.7419
# (55668, 1) (55668,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.8955487012863159, 0.7419354915618896]
# Real test data score:  0.6868039088884098
# ######################################################################
# WINDOW TYPE: vary - TRANSFORM TYPE: fft
# ######################################################################
# Epoch 1/5
# 1055/1055 [==============================] - 2s 1ms/step - loss: 5.4807 - accuracy: 0.5628
# Epoch 2/5
# 1055/1055 [==============================] - 2s 1ms/step - loss: 3.0347 - accuracy: 0.6157
# Epoch 3/5
# 1055/1055 [==============================] - 1s 1ms/step - loss: 1.7872 - accuracy: 0.6499
# Epoch 4/5
# 1055/1055 [==============================] - 1s 1ms/step - loss: 1.6548 - accuracy: 0.6329
# Epoch 5/5
# 1055/1055 [==============================] - 1s 1ms/step - loss: 1.0066 - accuracy: 0.6900
# 46/46 [==============================] - 0s 1ms/step - loss: 0.4831 - accuracy: 0.9369
# (55668, 1) (55668,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.4831458330154419, 0.9368565678596497]
# Real test data score:  0.7107853704102896
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: None
# ######################################################################
# Epoch 1/5
# 6761/6761 [==============================] - 15s 2ms/step - loss: 0.1798 - accuracy: 0.9300
# Epoch 2/5
# 6761/6761 [==============================] - 17s 3ms/step - loss: 0.1127 - accuracy: 0.9537
# Epoch 3/5
# 6761/6761 [==============================] - 10s 1ms/step - loss: 0.1072 - accuracy: 0.9553
# Epoch 4/5
# 6761/6761 [==============================] - 10s 1ms/step - loss: 0.1041 - accuracy: 0.9565
# Epoch 5/5
# 6761/6761 [==============================] - 10s 1ms/step - loss: 0.1019 - accuracy: 0.9573
# 174/174 [==============================] - 0s 1ms/step - loss: 0.1644 - accuracy: 0.9323
# (55660,) (55660,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.1644248515367508, 0.9322673082351685]
# Real test data score:  0.9108875314408911
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: dct
# ######################################################################
# Epoch 1/5
# 6761/6761 [==============================] - 13s 2ms/step - loss: 0.2497 - accuracy: 0.9219
# Epoch 2/5
# 6761/6761 [==============================] - 10s 1ms/step - loss: 0.1274 - accuracy: 0.9495
# Epoch 3/5
# 6761/6761 [==============================] - 11s 2ms/step - loss: 0.1157 - accuracy: 0.9523
# Epoch 4/5
# 6761/6761 [==============================] - 10s 1ms/step - loss: 0.1079 - accuracy: 0.9552
# Epoch 5/5
# 6761/6761 [==============================] - 10s 1ms/step - loss: 0.1061 - accuracy: 0.9559
# 174/174 [==============================] - 0s 1ms/step - loss: 0.1563 - accuracy: 0.9323
# (55660,) (55660,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.15630318224430084, 0.9322673082351685]
# Real test data score:  0.9086597197269134
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: fft
# ######################################################################
# Epoch 1/5
# 6761/6761 [==============================] - 13s 2ms/step - loss: 0.2161 - accuracy: 0.9227
# Epoch 2/5
# 6761/6761 [==============================] - 10s 2ms/step - loss: 0.1293 - accuracy: 0.9471
# Epoch 3/5
# 6761/6761 [==============================] - 10s 1ms/step - loss: 0.1204 - accuracy: 0.9495
# Epoch 4/5
# 6761/6761 [==============================] - 10s 1ms/step - loss: 0.1147 - accuracy: 0.9525
# Epoch 5/5
# 6761/6761 [==============================] - 10s 1ms/step - loss: 0.1107 - accuracy: 0.9537
# 174/174 [==============================] - 0s 1ms/step - loss: 0.1708 - accuracy: 0.9256
# (55660,) (55660,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.1708070933818817, 0.9256198406219482]
# Real test data score:  0.9080488681279195

# %%
window_size_list = [5, 15, 20, 25, 30]
window_type = 'fixed'
formatted_frames = None
for window_size in window_size_list: 
    skip_size = window_size
    data_formattor = FormatData(DATA_PATH)
    formatted_frames = data_formattor(window_type, window_size=window_size, skip_size=skip_size)
    for transform_type in [None, 'dct', 'fft']:
        print('#'*70)
        print('WINDOW TYPE: {} - TRANSFORM TYPE: {}'.format(window_type, transform_type))
        print('#'*70)
        model_trainer = DNNModelTrain(formatted_frames, window_type, transform_type)
        model_trainer()
# Out:
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: None
# ######################################################################
# Epoch 1/5
# 13522/13522 [==============================] - 22s 2ms/step - loss: 0.1536 - accuracy: 0.9421
# Epoch 2/5
# 13522/13522 [==============================] - 21s 2ms/step - loss: 0.1006 - accuracy: 0.9598
# Epoch 3/5
# 13522/13522 [==============================] - 20s 1ms/step - loss: 0.0928 - accuracy: 0.9625
# Epoch 4/5
# 13522/13522 [==============================] - 21s 2ms/step - loss: 0.0890 - accuracy: 0.9635
# Epoch 5/5
# 13522/13522 [==============================] - 20s 2ms/step - loss: 0.0871 - accuracy: 0.9641
# 348/348 [==============================] - 1s 1ms/step - loss: 0.1663 - accuracy: 0.9350
# (55665,) (55665,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.1663130819797516, 0.934968113899231]
# Real test data score:  0.927351118296955
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: dct
# ######################################################################
# Epoch 1/5
# 13522/13522 [==============================] - 23s 2ms/step - loss: 0.2062 - accuracy: 0.9346
# Epoch 2/5
# 13522/13522 [==============================] - 20s 1ms/step - loss: 0.1040 - accuracy: 0.9584
# Epoch 3/5
# 13522/13522 [==============================] - 20s 1ms/step - loss: 0.0986 - accuracy: 0.9601
# Epoch 4/5
# 13522/13522 [==============================] - 20s 1ms/step - loss: 0.0964 - accuracy: 0.9615
# Epoch 5/5
# 13522/13522 [==============================] - 20s 1ms/step - loss: 0.0928 - accuracy: 0.9620
# 348/348 [==============================] - 1s 1ms/step - loss: 0.1933 - accuracy: 0.9228
# (55665,) (55665,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.19330506026744843, 0.9228420257568359]
# Real test data score:  0.9172370430252402
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: fft
# ######################################################################
# Epoch 1/5
# 13522/13522 [==============================] - 23s 2ms/step - loss: 0.1805 - accuracy: 0.9365
# Epoch 2/5
# 13522/13522 [==============================] - 18s 1ms/step - loss: 0.1066 - accuracy: 0.9570
# Epoch 3/5
# 13522/13522 [==============================] - 18s 1ms/step - loss: 0.0992 - accuracy: 0.9602
# Epoch 4/5
# 13522/13522 [==============================] - 23s 2ms/step - loss: 0.0947 - accuracy: 0.9614
# Epoch 5/5
# 13522/13522 [==============================] - 19s 1ms/step - loss: 0.0922 - accuracy: 0.9623
# 348/348 [==============================] - 1s 1ms/step - loss: 0.1521 - accuracy: 0.9386
# (55665,) (55665,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.15209589898586273, 0.9385610222816467]
# Real test data score:  0.931411120093416
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: None
# ######################################################################
# Epoch 1/5
# 4508/4508 [==============================] - 8s 1ms/step - loss: 0.2264 - accuracy: 0.9130
# Epoch 2/5
# 4508/4508 [==============================] - 6s 1ms/step - loss: 0.1248 - accuracy: 0.9473
# Epoch 3/5
# 4508/4508 [==============================] - 6s 1ms/step - loss: 0.1145 - accuracy: 0.9516
# Epoch 4/5
# 4508/4508 [==============================] - 6s 1ms/step - loss: 0.1111 - accuracy: 0.9524
# Epoch 5/5
# 4508/4508 [==============================] - 6s 1ms/step - loss: 0.1069 - accuracy: 0.9540
# 116/116 [==============================] - 0s 1ms/step - loss: 0.1672 - accuracy: 0.9259
# (55665,) (55665,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.16722996532917023, 0.9258959889411926]
# Real test data score:  0.8902721638372406
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: dct
# ######################################################################
# Epoch 1/5
# 4508/4508 [==============================] - 7s 1ms/step - loss: 0.8010 - accuracy: 0.8958
# Epoch 2/5
# 4508/4508 [==============================] - 6s 1ms/step - loss: 0.1625 - accuracy: 0.9395
# Epoch 3/5
# 4508/4508 [==============================] - 6s 1ms/step - loss: 0.1327 - accuracy: 0.9455
# Epoch 4/5
# 4508/4508 [==============================] - 6s 1ms/step - loss: 0.1217 - accuracy: 0.9488
# Epoch 5/5
# 4508/4508 [==============================] - 6s 1ms/step - loss: 0.1156 - accuracy: 0.9513
# 116/116 [==============================] - 0s 1ms/step - loss: 0.2135 - accuracy: 0.9173
# (55665,) (55665,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.21354345977306366, 0.9172729849815369]
# Real test data score:  0.8880804814515405
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: fft
# ######################################################################
# Epoch 1/5
# 4508/4508 [==============================] - 7s 1ms/step - loss: 0.3174 - accuracy: 0.9015
# Epoch 2/5
# 4508/4508 [==============================] - 6s 1ms/step - loss: 0.1529 - accuracy: 0.9371
# Epoch 3/5
# 4508/4508 [==============================] - 6s 1ms/step - loss: 0.1335 - accuracy: 0.9428
# Epoch 4/5
# 4508/4508 [==============================] - 6s 1ms/step - loss: 0.1253 - accuracy: 0.9460
# Epoch 5/5
# 4508/4508 [==============================] - 6s 1ms/step - loss: 0.1212 - accuracy: 0.9484
# 116/116 [==============================] - 0s 1ms/step - loss: 0.2461 - accuracy: 0.9116
# (55665,) (55665,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.2460615336894989, 0.9116141200065613]
# Real test data score:  0.8826731339261654
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: None
# ######################################################################
# Epoch 1/5
# 3381/3381 [==============================] - 5s 1ms/step - loss: 0.2613 - accuracy: 0.8993
# Epoch 2/5
# 3381/3381 [==============================] - 5s 1ms/step - loss: 0.1398 - accuracy: 0.9387
# Epoch 3/5
# 3381/3381 [==============================] - 5s 1ms/step - loss: 0.1306 - accuracy: 0.9423
# Epoch 4/5
# 3381/3381 [==============================] - 5s 1ms/step - loss: 0.1254 - accuracy: 0.9439
# Epoch 5/5
# 3381/3381 [==============================] - 5s 1ms/step - loss: 0.1219 - accuracy: 0.9464
# 87/87 [==============================] - 0s 1ms/step - loss: 0.1230 - accuracy: 0.9522
# (55660,) (55660,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.12304845452308655, 0.9522098302841187]
# Real test data score:  0.8791591807402084
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: dct
# ######################################################################
# Epoch 1/5
# 3381/3381 [==============================] - 5s 1ms/step - loss: 0.8260 - accuracy: 0.8768
# Epoch 2/5
# 3381/3381 [==============================] - 5s 1ms/step - loss: 0.2036 - accuracy: 0.9270
# Epoch 3/5
# 3381/3381 [==============================] - 5s 1ms/step - loss: 0.1616 - accuracy: 0.9357
# Epoch 4/5
# 3381/3381 [==============================] - 5s 1ms/step - loss: 0.1428 - accuracy: 0.9379
# Epoch 5/5
# 3381/3381 [==============================] - 5s 1ms/step - loss: 0.1324 - accuracy: 0.9414
# 87/87 [==============================] - 0s 1ms/step - loss: 0.1259 - accuracy: 0.9519
# (55660,) (55660,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.12587805092334747, 0.9518505334854126]
# Real test data score:  0.8799496945742005
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: fft
# ######################################################################
# Epoch 1/5
# 3381/3381 [==============================] - 5s 1ms/step - loss: 0.4283 - accuracy: 0.8884
# Epoch 2/5
# 3381/3381 [==============================] - 5s 1ms/step - loss: 0.1762 - accuracy: 0.9277
# Epoch 3/5
# 3381/3381 [==============================] - 5s 1ms/step - loss: 0.1531 - accuracy: 0.9353
# Epoch 4/5
# 3381/3381 [==============================] - 5s 1ms/step - loss: 0.1463 - accuracy: 0.9361
# Epoch 5/5
# 3381/3381 [==============================] - 5s 1ms/step - loss: 0.1388 - accuracy: 0.9388
# 87/87 [==============================] - 0s 1ms/step - loss: 0.1406 - accuracy: 0.9468
# (55660,) (55660,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.1406429409980774, 0.9468199610710144]
# Real test data score:  0.8741645706072584
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: None
# ######################################################################
# Epoch 1/5
# 2705/2705 [==============================] - 3s 1ms/step - loss: 0.2366 - accuracy: 0.9091
# Epoch 2/5
# 2705/2705 [==============================] - 3s 1ms/step - loss: 0.1359 - accuracy: 0.9443
# Epoch 3/5
# 2705/2705 [==============================] - 3s 1ms/step - loss: 0.1261 - accuracy: 0.9462
# Epoch 4/5
# 2705/2705 [==============================] - 3s 1ms/step - loss: 0.1204 - accuracy: 0.9488
# Epoch 5/5
# 2705/2705 [==============================] - 3s 1ms/step - loss: 0.1128 - accuracy: 0.9516
# 70/70 [==============================] - 0s 899us/step - loss: 0.0651 - accuracy: 0.9762
# (55650,) (55650,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.06505477428436279, 0.976190447807312]
# Real test data score:  0.8830548068283918
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: dct
# ######################################################################
# Epoch 1/5
# 2705/2705 [==============================] - 4s 1ms/step - loss: 0.9002 - accuracy: 0.8884
# Epoch 2/5
# 2705/2705 [==============================] - 3s 1ms/step - loss: 0.1884 - accuracy: 0.9331
# Epoch 3/5
# 2705/2705 [==============================] - 3s 1ms/step - loss: 0.1510 - accuracy: 0.9379
# Epoch 4/5
# 2705/2705 [==============================] - 3s 1ms/step - loss: 0.1349 - accuracy: 0.9443
# Epoch 5/5
# 2705/2705 [==============================] - 3s 1ms/step - loss: 0.1285 - accuracy: 0.9459
# 70/70 [==============================] - 0s 957us/step - loss: 0.0583 - accuracy: 0.9856
# (55650,) (55650,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.0583307258784771, 0.9856244325637817]
# Real test data score:  0.8857322551662175
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: fft
# ######################################################################
# Epoch 1/5
# 2705/2705 [==============================] - 4s 1ms/step - loss: 0.4194 - accuracy: 0.8940
# Epoch 2/5
# 2705/2705 [==============================] - 3s 1ms/step - loss: 0.1823 - accuracy: 0.9306
# Epoch 3/5
# 2705/2705 [==============================] - 3s 1ms/step - loss: 0.1628 - accuracy: 0.9365
# Epoch 4/5
# 2705/2705 [==============================] - 3s 1ms/step - loss: 0.1457 - accuracy: 0.9411
# Epoch 5/5
# 2705/2705 [==============================] - 3s 1ms/step - loss: 0.1358 - accuracy: 0.9428
# 70/70 [==============================] - 0s 899us/step - loss: 0.1102 - accuracy: 0.9636
# (55650,) (55650,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.11024263501167297, 0.9636118412017822]
# Real test data score:  0.872848158131177
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: None
# ######################################################################
# Epoch 1/5
# 2254/2254 [==============================] - 3s 1ms/step - loss: 0.2450 - accuracy: 0.9051
# Epoch 2/5
# 2254/2254 [==============================] - 2s 1ms/step - loss: 0.1321 - accuracy: 0.9446
# Epoch 3/5
# 2254/2254 [==============================] - 2s 1ms/step - loss: 0.1202 - accuracy: 0.9485
# Epoch 4/5
# 2254/2254 [==============================] - 2s 1ms/step - loss: 0.1142 - accuracy: 0.9520
# Epoch 5/5
# 2254/2254 [==============================] - 3s 1ms/step - loss: 0.1108 - accuracy: 0.9538
# 58/58 [==============================] - 0s 905us/step - loss: 0.0564 - accuracy: 0.9822
# (55650,) (55650,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.05642062425613403, 0.9822102189064026]
# Real test data score:  0.8827313566936208
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: dct
# ######################################################################
# Epoch 1/5
# 2254/2254 [==============================] - 3s 1ms/step - loss: 1.6845 - accuracy: 0.8774
# Epoch 2/5
# 2254/2254 [==============================] - 3s 1ms/step - loss: 0.2171 - accuracy: 0.9305
# Epoch 3/5
# 2254/2254 [==============================] - 3s 1ms/step - loss: 0.1665 - accuracy: 0.9394
# Epoch 4/5
# 2254/2254 [==============================] - 3s 1ms/step - loss: 0.1453 - accuracy: 0.9444
# Epoch 5/5
# 2254/2254 [==============================] - 3s 1ms/step - loss: 0.1345 - accuracy: 0.9471
# 58/58 [==============================] - 0s 912us/step - loss: 0.0804 - accuracy: 0.9806
# (55650,) (55650,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.08044850826263428, 0.9805929660797119]
# Real test data score:  0.8817969451931716
# ######################################################################
# WINDOW TYPE: fixed - TRANSFORM TYPE: fft
# ######################################################################
# Epoch 1/5
# 2254/2254 [==============================] - 3s 1ms/step - loss: 0.6160 - accuracy: 0.8842
# Epoch 2/5
# 2254/2254 [==============================] - 2s 1ms/step - loss: 0.2053 - accuracy: 0.9242
# Epoch 3/5
# 2254/2254 [==============================] - 2s 1ms/step - loss: 0.1743 - accuracy: 0.9333
# Epoch 4/5
# 2254/2254 [==============================] - 3s 1ms/step - loss: 0.1543 - accuracy: 0.9381
# Epoch 5/5
# 2254/2254 [==============================] - 3s 1ms/step - loss: 0.1461 - accuracy: 0.9407
# 58/58 [==============================] - 0s 1ms/step - loss: 0.1057 - accuracy: 0.9736
# (55650,) (55650,)
#
#         ##################################
#         #            DNN model            #
#         ##################################
#
# Windowed test data score:  [0.1056579202413559, 0.9735848903656006]
# Real test data score:  0.8779155435759209

# %% [markdown]
# **TODOs: Overlaping windows**
